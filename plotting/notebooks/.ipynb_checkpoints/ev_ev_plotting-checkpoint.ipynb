# %%
from pythtb import * # import TB model class
import numpy as np

import matplotlib.pyplot as plt

import ase
import ase.io
import ase.neighborlist
import ase.visualize.plot

# %%
geom = ase.io.read("./clars_goblet.xyz")
lat = [
    [1.0,0.0],
    [0.0,1.0]
]
geom.center(about=0.0)
orb = []
for at in geom:
    orb.append(at.position[:2])

# %%
for i_at, j_at in zip(i_arr, j_arr):
    if i_at < j_at:
        my_model.set_hop(t, i_at, j_at)
            
my_model.visualize(0, 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dbe3f4d96c46> in <module>
#       1
# ----> 2 for i_at, j_at in zip(i_arr, j_arr):
#       3     if i_at < j_at:
#       4         my_model.set_hop(t, i_at, j_at)
#       5
#
# NameError: name 'i_arr' is not defined

# %%
f = open("clars_eigenval_no_hub.txt","r")
#print(f.readline())


num_lines = sum(1 for line in open('clars_eigenval_no_hub.txt', "r"))
#print(num_lines)


evals = np.zeros(num_lines, dtype=float)
evecs_shape = (num_lines, num_lines)
evecs = np.zeros(evecs_shape, dtype=complex)

counter = 0
word_count = 0
for line in f:
    #print(line)
    splitted_line = line.split(' ')

    evals[counter] = np.float64(splitted_line[0])
    splitted_line.pop(0)

    x = ''
    y = ''
    y_turn = False
    for i in splitted_line[0]:
        if(i == '(' or i == ' '):
            continue
        if(i != ',' and y_turn == False):
            x += i
        elif(i == ','):
            y_turn = True
            continue
        elif(i != ')'):
            y += i
        else:
            
            evecs[counter, word_count] = complex(float(x), float(y))
            x = ''
            y = ''
            word_count = word_count + 1
            y_turn = False

    
    counter = counter + 1
    word_count = 0
    
print(evecs)
# Out:
# [[ 2.44466e-01+0.j  2.35114e-03+0.j  2.71008e-01+0.j ...  5.24612e-04+0.j
#    7.02622e-02+0.j  6.75745e-04+0.j]
#  [ 2.35114e-03+0.j -2.44466e-01+0.j  2.60641e-03+0.j ... -5.45479e-02+0.j
#    6.75745e-04+0.j -7.02622e-02+0.j]
#  [-7.26124e-02+0.j -7.27353e-03+0.j -1.59467e-01+0.j ... -8.60457e-03+0.j
#   -1.15575e-01+0.j -1.15770e-02+0.j]
#  ...
#  [ 7.29754e-02+0.j -2.30312e-04+0.j -1.60264e-01+0.j ... -2.72459e-04+0.j
#   -1.16153e-01+0.j  3.66581e-04+0.j]
#  [-2.44477e-01+0.j -1.38778e-16+0.j  2.71021e-01-0.j ...  1.76942e-16+0.j
#    7.02654e-02-0.j -9.71445e-17+0.j]
#  [ 8.97133e-17+0.j -2.44477e-01+0.j -9.88216e-17+0.j ... -5.45504e-02+0.j
#   -7.62900e-17+0.j  7.02654e-02+0.j]]

# %%
ed = num_lines//2
print(num_lines, ed)
homo = ed-1
# Out:
# 76 38

# %%
plt.plot(evals[ed-4:ed+4], 'o')
plt.show()
for ev in evals[ed-4:ed+4]:
    print(ev)
# Out:
# -1.38589
# -1.38589
# -1.0
# -1.0
# -1.0
# -1.0
# -0.614112
# -0.614112

# %%
def visualize_backbone(ax, atoms):
    i_arr, j_arr = ase.neighborlist.neighbor_list('ij', atoms, 1.8)
    for i, j in zip(i_arr, j_arr):
        if i < j:
            p1 = atoms.positions[i]
            p2 = atoms.positions[j]
            ax.plot([p1[0], p2[0]], [p1[1], p2[1]], 'k-', linewidth=3.0, solid_capstyle='round')
            
def visualize_evec(ax, atoms, evec):
    for at, e in zip(atoms, evec):
        p = at.position
        mod = np.abs(e)
        phase = np.angle(e)/np.pi
        col = (1.0-phase, 0.0, phase)
        circ = plt.Circle(p[:2], mod, color=col, zorder=10)
        ax.add_artist(circ)

# %%
for ind in range(ed-4, ed+4):
    fig=plt.figure(figsize=(6,6))
    ax = plt.gca()
    ax.set_aspect('equal')
    visualize_backbone(ax, geom)
    visualize_evec(ax, geom, evecs[ind,:])
    plt.axis('off')
    xmin = np.min(geom.positions[:, 0])-0.7
    xmax = np.max(geom.positions[:, 0])+0.7
    ymin = np.min(geom.positions[:, 1])+0.2
    ymax = np.max(geom.positions[:, 1])+0.2
    plt.xlim([xmin, xmax])
    plt.text(xmin+1.0, ymin-1.6, "E = %.2f eV" % evals[ind], fontsize=20)
    plt.savefig("./figures_no_hub/orb_%d_%d.png" % (ind, ind-homo), dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ((2.0, 0.0, -1.0), None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-ba000f8725d3> in <module>
#       4     ax.set_aspect('equal')
#       5     visualize_backbone(ax, geom)
# ----> 6     visualize_evec(ax, geom, evecs[ind,:])
#       7     plt.axis('off')
#       8     xmin = np.min(geom.positions[:, 0])-0.7
#
# <ipython-input-7-516b8ab71341> in visualize_evec(ax, atoms, evec)
#      13         phase = np.angle(e)/np.pi
#      14         col = (1.0-phase, 0.0, phase)
# ---> 15         circ = plt.Circle(p[:2], mod, color=col, zorder=10)
#      16         ax.add_artist(circ)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, xy, radius, **kwargs)
#    1517
#    1518         """
# -> 1519         Ellipse.__init__(self, xy, radius * 2, radius * 2, **kwargs)
#    1520         self.radius = radius
#    1521
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#    1461         %(Patch)s
#    1462         """
# -> 1463         Patch.__init__(self, **kwargs)
#    1464
#    1465         self.center = xy
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      83                 warnings.warn("Setting the 'color' property will override"
#      84                               "the edgecolor or facecolor properties. ")
# ---> 85             self.set_color(color)
#      86         else:
#      87             self.set_edgecolor(edgecolor)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in set_color(self, c)
#     330                For setting the edge or face color individually.
#     331         """
# --> 332         self.set_facecolor(c)
#     333         self.set_edgecolor(c)
#     334
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in set_facecolor(self, color)
#     313         """
#     314         self._original_facecolor = color
# --> 315         self._set_facecolor(color)
#     316
#     317     def set_fc(self, color):
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in _set_facecolor(self, color)
#     303             color = mpl.rcParams['patch.facecolor']
#     304         alpha = self._alpha if self._fill else 0
# --> 305         self._facecolor = colors.to_rgba(color, alpha)
#     306         self.stale = True
#     307
#
# /usr/local/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 168         rgba = _to_rgba_no_colorcycle(c, alpha)
#     169         try:
#     170             _colors_full_map.cache[c, alpha] = rgba
#
# /usr/local/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     227         c = c[:3] + (alpha,)
#     228     if any(elem < 0 or elem > 1 for elem in c):
# --> 229         raise ValueError("RGBA values should be within 0-1 range")
#     230     return c
#     231
#
# ValueError: RGBA values should be within 0-1 range

# %%
fig = plt.figure(figsize=(2, 12))
ax = plt.gca()
for ev in evals[ed-ed:ed*2]:
    col = 'blue'
    if ev < 0.0:
        col = 'red'
    plt.plot([0.1, 0.9], [ev, ev], '-', color=col, lw=3.0, solid_capstyle='round')
    
ax.get_xaxis().set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
plt.xlim(0.0, 1.0)
plt.ylim(-3.0, 3.0)
plt.ylabel("Energy (eV)")
plt.savefig("./levels.png", dpi=300, bbox_inches='tight')
