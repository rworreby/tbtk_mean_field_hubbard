# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
from sknano.generators import GrapheneGenerator

# %%
armchair_nanoribbon = GrapheneGenerator(armchair_edge_length=100, zigzag_edge_length=10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-44f61f577733> in <module>()
# ----> 1 armchair_nanoribbon = GrapheneGenerator(armchair_edge_length=100, zigzag_edge_length=10)
#
# /home/worreby/.local/lib/python3.6/site-packages/sknano/generators/_base.py in __init__(self, autogen, *args, **kwargs)
#      52
#      53         if autogen:
# ---> 54             self.generate()
#      55
#      56     def generate(self):
#
# /home/worreby/.local/lib/python3.6/site-packages/sknano/generators/_graphene_generator.py in generate(self)
#      81                 layer.translate(self.layer_shift)
#      82             [setattr(atom, 'mol', nlayer + 1) for atom in layer]
# ---> 83             layer.rotate(angle=self.layer_rotation_angles[nlayer], axis='z')
#      84             self.atoms.extend(layer)
#      85             self.layers.append(layer)
#
# /home/worreby/.local/lib/python3.6/site-packages/sknano/core/atoms/_atoms.py in rotate(self, **kwargs)
#     556         """
#     557         if kwargs.get('transform_matrix', None) is None:
# --> 558             kwargs['transform_matrix'] = rotation_matrix(**kwargs)
#     559         [atom.rotate(**kwargs) for atom in self]
#     560
#
# /home/worreby/.local/lib/python3.6/site-packages/sknano/core/math/_transforms.py in rotation_matrix(angle, axis, anchor_point, rot_point, from_vector, to_vector, degrees, verbose, **kwargs)
#     316                                  rot_point=rot_point, from_vector=from_vector,
#     317                                  to_vector=to_vector, degrees=degrees,
# --> 318                                  verbose=verbose, **kwargs)
#     319     return Rmat[:-1, :-1]
#     320
#
# /home/worreby/.local/lib/python3.6/site-packages/sknano/core/math/_transforms.py in transformation_matrix(angle, axis, anchor_point, rot_point, from_vector, to_vector, degrees, verbose, **kwargs)
#     538             Tmat = np.zeros((4, 4))
#     539
# --> 540             if np.allclose(v, I[:3, 0]):
#     541                 Tmat[:3, :3] = Rx(angle)
#     542             elif np.allclose(v, I[:3, 1]):
#
# <__array_function__ internals> in allclose(*args, **kwargs)
#
# /home/worreby/.local/lib/python3.6/site-packages/numpy/core/numeric.py in allclose(a, b, rtol, atol, equal_nan)
#    2169
#    2170     """
# -> 2171     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2172     return bool(res)
#    2173
#
# <__array_function__ internals> in isclose(*args, **kwargs)
#
# /home/worreby/.local/lib/python3.6/site-packages/numpy/core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2269     xfin = isfinite(x)
#    2270     yfin = isfinite(y)
# -> 2271     if all(xfin) and all(yfin):
#    2272         return within_tol(x, y, atol, rtol)
#    2273     else:
#
# <__array_function__ internals> in all(*args, **kwargs)
#
# /home/worreby/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in all(a, axis, out, keepdims)
#    2349
#    2350     """
# -> 2351     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#    2352
#    2353
#
# /home/worreby/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      87             else:
# ---> 88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
#      90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# /home/worreby/.local/lib/python3.6/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      46
#      47 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 48     return umr_all(a, axis, dtype, out, keepdims)
#      49
#      50 def _count_reduce_items(arr, axis):
#
# /home/worreby/.local/lib/python3.6/site-packages/sknano/core/math/_vector.py in __array_wrap__(self, obj, context)
#     174     def __array_wrap__(self, obj, context=None):
#     175         res = np.ndarray.__array_wrap__(self, obj, context)
# --> 176         return self.__class__(res.__array__(), p0=self.p0)
#     177
#     178     def __str__(self):
#
# /home/worreby/.local/lib/python3.6/site-packages/sknano/core/math/_vector.py in __new__(cls, v, nd, p0, p, dtype, copy)
#     102         if isinstance(v, (tuple, list, np.ndarray)):
#     103             try:
# --> 104                 for i, coord in enumerate(v[:]):
#     105                     if coord is None:
#     106                         v[i] = 0.0
#
# IndexError: too many indices for array

# %%
armchair_nanoribbon.save()
